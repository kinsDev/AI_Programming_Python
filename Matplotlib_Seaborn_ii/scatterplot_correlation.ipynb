# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt 
# %matplotlib inline

# Read the CSV file
fuel_econ = pd.read_csv('fuel_econ.csv')
fuel_econ.head(6)

#scatter plot
plt.scatter(data = fuel_econ, x = 'displ', y = 'comb')
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff. (mpg)')

# %%
sb.regplot(data = fuel_econ, x = 'displ', y = 'comb');
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff. (mpg)')

# %%
def log_trans(x, inverse = False):
    if not inverse:
        return np.log10(x)
    else:
        return np.power(10, x)

fuel_econ['comb_log'] = fuel_econ['comb'].apply(log_trans)
sb.regplot(data=fuel_econ, x='displ', y='comb_log')
tick_locs = [10, 20, 50, 100]
plt.yticks(log_trans(tick_locs), tick_locs)
# Out:
# ([<matplotlib.axis.YTick at 0x1d239e9dcd0>,
#   <matplotlib.axis.YTick at 0x1d239e27510>,
#   <matplotlib.axis.YTick at 0x1d239e9fcd0>,
#   <matplotlib.axis.YTick at 0x1d239ed1010>],
#  [Text(0, 1.0, '10'),
#   Text(0, 1.3010299956639813, '20'),
#   Text(0, 1.6989700043360187, '50'),
#   Text(0, 2.0, '100')])
