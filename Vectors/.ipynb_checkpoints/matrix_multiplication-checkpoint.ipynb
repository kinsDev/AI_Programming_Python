# %%
# Graphing a Vector  𝑣⃗  Decomposed into Basis Vectors  𝑖̂ ⃗ and  𝑗̂ 

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# define vector v
v = np.array([-1, 2])

# Define basis vector i_hat as unit vector
i_hat = np.array([1, 0])

# Define basis vector j_hat as unit vector
j_hat = np.array([0, 1])

# Define v_ihat - as x multiplied by basis vector ihat -  to access x from vector v - v[0]
v_ihat = v[0] * i_hat

# Define v_jhat_t - as y multiplied by basis vector jhat - to access y from vector v - v[1]
v_jhat = v[1] * j_hat

# Plot that graphically shows vector v (color='b') - whose position can be  
# decomposed into v_ihat and v_jhat  

# Creates axes of plot referenced 'ax'
ax = plt.axes()

# Plots red dot at origin (0,0)
ax.plot(0, 0, 'r')

# Plots vector v_ihat as dotted green arrow starting at origin 0,0
ax.arrow(0, 0, *v_ihat, color = 'g', linestyle = 'dotted', linewidth = 2.5, head_width = 0.30, head_length = 0.35)

# Plots vector v_jhat as dotted red arrow starting at origin defined by v_ihat
ax.arrow(v_ihat[0], v_ihat[1], *v_jhat, color = 'r', linestyle = 'dotted', linewidth = 2.5, head_width = 0.30, head_length = 0.35)

# Plots vector v as blue arrow starting at origin 0,0
ax.arrow(0, 0, *v, color = 'b', linewidth = 2.5, head_width = 0.30, head_length = 0.35)

# Sets limit for plot for x-axis
plt.xlim(-4, 2)

# Set major ticks for x-axis
major_xticks = np.arange(-4, 2)
ax.set_xticks(major_xticks)

# Sets limit for plot for y-axis
plt.yticks(-2, 4)

# Set major ticks for y-axis
major_yticks = np.arange(-2, 3)
ax.set_yticks(major_yticks)

# Creates gridlines for only major tick marks
plt.grid(b = True, which = 'major')

# Displays final plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 48
#      45 ax.set_xticks(major_xticks)
#      47 # Sets limit for plot for y-axis
# ---> 48 plt.yticks(-2, 4)
#      50 # Set major ticks for y-axis
#      51 major_yticks = np.arange(-2, 3)
#
# File D:\Anaconda3\Lib\site-packages\matplotlib\pyplot.py:2116, in yticks(ticks, labels, minor, **kwargs)
#    2113         raise TypeError("yticks(): Parameter 'labels' can't be set "
#    2114                         "without setting 'ticks'")
#    2115 else:
# -> 2116     locs = ax.set_yticks(ticks, minor=minor)
#    2118 labels_out: list[Text] = []
#    2119 if labels is None:
#
# File D:\Anaconda3\Lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ...
